# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-intro/documents.json

# %%
import minsearch

# %%
import json

# %%
with open('documents.json', 'rt') as f_in:
    docs_raw = json.load(f_in)

# %%
documents = []

for course_dict in docs_raw:
    for doc in course_dict['documents']:
        doc['course'] = course_dict['course']
        documents.append(doc)

# %%
index = minsearch.Index(
    text_fields=["question", "text", "section"],
    keyword_fields=["course"]
)

# %%
q = 'the course has already started, can I still enroll?'

# %%
index.fit(documents)

# %%
from openai import OpenAI
import os

# %%
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTERAI_API_KEY"),
)

# %%
def search(query):
    boost = {'question': 3.0, 'section': 0.5}

    results = index.search(
        query = q,
        filter_dict={'course':'data-engineering-zoomcamp'},
        boost_dict=boost,
        num_results=5
    )
    return results

# %%
def build_prompt(query, search_results):
    prompt_template = """
You're a course teaching assistant. Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT:
{context}
""".strip()

    context_template = """
Q: {question}
A: {text}
""".strip()

    context = ""
    
    for doc in search_results:
        context = context + context_template.format(question=doc['question'], text=doc['text']) + "\n\n"
    
    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
def llm(prompt):
    response = client.chat.completions.create(
      model="qwen/qwen3-4b:free",
      messages=[
        {
          "role": "user",
          "content": prompt,
        },
      ]
    )
    
    return response.choices[0].message.content

# %%
query = 'how do I enroll the course?'
def rag(query):    
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    answer = llm(prompt)
    return answer

# %%
rag(query)
# Out:
# 'To enroll in the course, follow these steps:  \n1. **Register before the course starts** using the provided link (even though the specific URL isn\'t listed in the context, you would use the one mentioned in the FAQ).  \n2. **Join the course Telegram channel** for announcements.  \n3. **Subscribe to the course public Google Calendar** (note: it is accessible only via desktop).  \n4. **Join the Slack channel** on DataTalks.Club and join the specific course channel.  \n\nThese steps ensure you are prepared for the course start on **15th Jan 2024 at 17:00**, which begins with the first "Office Hours" live session. No further action is needed to enroll once the course has started, as eligibility to submit homework remains open for those who join after the start date.'

# %%
import requests 

docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %%
from elasticsearch import Elasticsearch

# %%
es_client = Elasticsearch('http://localhost:9200')

# %%
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "section": {"type": "text"},
            "question": {"type": "text"},
            "course": {"type": "keyword"} 
        }
    }
}

index_name = "course-questions"

es_client.indices.create(index=index_name, body=index_settings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'course-questions'})

# %%
documents[0]
# Out:
# {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#  'section': 'General course-related questions',
#  'question': 'Course - When will the course start?',
#  'course': 'data-engineering-zoomcamp'}

# %%
from tqdm.auto import tqdm

# %%
for doc in tqdm(documents):
    es_client.index(index=index_name, document=doc)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
query = 'How do I execute a command in a running docker container?'

# %%
def elastic_search(query):
    search_query = {
        "size": 5,
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["question^4", "text", "section"],
                        "type": "best_fields"
                    }
                },
                "filter": {
                    "term": {
                        "course": "machine-learning-zoomcamp"
                    }
                }
            }
        }
    }

    response = es_client.search(index=index_name, body=search_query)
    result_docs = []
    
    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])

    print(result_docs[2])
    return result_docs

# %%
search_results = elastic_search(query)
prompt = build_prompt(query, search_results)
print(len(prompt))
# Out:
# {'text': 'You can copy files from your local machine into a Docker container using the docker cp command. Here\'s how to do it:\nIn the Dockerfile, you can provide the folder containing the files that you want to copy over. The basic syntax is as follows:\nCOPY ["src/predict.py", "models/xgb_model.bin", "./"]\t\t\t\t\t\t\t\t\t\t\tGopakumar Gopinathan', 'section': '5. Deploying Machine Learning Models', 'question': 'How do I copy files from a different folder into docker container’s working directory?', 'course': 'machine-learning-zoomcamp'}
# 2714

# %%
import tiktoken
encoding = tiktoken.encoding_for_model("gpt-4o")
print(len(encoding.encode(prompt)))
# Out:
# 621

# %%
def rag(query):
    search_results = elastic_search(query)
    prompt = build_prompt(query, search_results)
    answer = llm(prompt)
    return answer

# %%
rag(query)
# Out:
# {'text': 'You can copy files from your local machine into a Docker container using the docker cp command. Here\'s how to do it:\nIn the Dockerfile, you can provide the folder containing the files that you want to copy over. The basic syntax is as follows:\nCOPY ["src/predict.py", "models/xgb_model.bin", "./"]\t\t\t\t\t\t\t\t\t\t\tGopakumar Gopinathan', 'section': '5. Deploying Machine Learning Models', 'question': 'How do I copy files from a different folder into docker container’s working directory?', 'course': 'machine-learning-zoomcamp'}
# 'To execute a command in a running Docker container, follow these steps:  \n\n1. **Identify the container ID**:  \n   Run `docker ps` to list all running containers and find the ID of the target container.  \n\n2. **Execute the command**:  \n   Use `docker exec` to run a command in the specified container. For example:  \n   ```bash  \n   docker exec -it <container-id> <command>  \n   ```  \n   Replace `<container-id>` with the actual container ID from `docker ps`, and `<command>` with the desired command (e.g., `bash`, `python`, etc.).  \n\n**Example**:  \nIf the container ID is `1e5a1b663052`, execute a bash shell with:  \n```bash  \ndocker exec -it 1e5a1b663052 bash  \n```  \n\n**Note**: On Windows with GitBash, if you encounter a "TTY not available" error, prefix the command with `winpty` (e.g., `winpty docker exec -it <container-id> bash`).  \n\nThis approach allows you to interactively run commands in a running container.'
